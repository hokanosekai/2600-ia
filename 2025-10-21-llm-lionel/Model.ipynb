# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "hemanthpingali/phishing-url",
    "Testing.parquet"
)

df_train = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "hemanthpingali/phishing-url",
    "Training.parquet"
)

# %%
print(df.head())
# print(df.shape)
# print(df.info())
# print(df['url'].nunique())
df['status'].value_counts()
print(df_train['status'].value_counts())
# Out:
#                                                  url  length_url  \
# 0               https://clubedemilhagem.com/home.php          36
# 1  http://www.medicalnewstoday.com/articles/18893...          51
# 2     https://en.wikipedia.org/wiki/NBC_Nightly_News          46
# 3  http://secure.web894.com/customer_center/custo...         185
# 4  https://en.wikipedia.org/wiki/Transaction_proc...          52
#
#    length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  ...  \
# 0               19   0        2           0      0      0       0      0  ...
# 1               24   0        3           0      0      0       0      0  ...
# 2               16   0        2           0      0      0       0      0  ...
# 3               17   1        2           1      0      1       2      0  ...
# 4               16   0        2           0      0      0       0      0  ...
#
#    domain_in_title  domain_with_copyright  whois_registered_domain  \
# ...

# %%
# X_test = df.drop("status", axis=1) # Features
# X_train = df_train.drop("status", axis=1) # Features
# y_train = df_train["status"]  # Target variable
# y_test = df["status"]  # Target variable
X = df.drop("status", axis=1)
y = df["status"]  # Target variable

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.4, random_state=42, stratify=y
)

# %%
numerical_features = X.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X.select_dtypes(include=['object']).columns
print("Numerical features:", numerical_features)
print("Categorical features:", categorical_features)
# Out:
# Numerical features: Index(['length_url', 'length_hostname', 'ip', 'nb_dots', 'nb_hyphens', 'nb_at',
#        'nb_qm', 'nb_and', 'nb_or', 'nb_eq', 'nb_underscore', 'nb_tilde',
#        'nb_percent', 'nb_slash', 'nb_star', 'nb_colon', 'nb_comma',
#        'nb_semicolumn', 'nb_dollar', 'nb_space', 'nb_www', 'nb_com',
#        'nb_dslash', 'http_in_path', 'https_token', 'ratio_digits_url',
#        'ratio_digits_host', 'punycode', 'port', 'tld_in_path',
#        'tld_in_subdomain', 'abnormal_subdomain', 'nb_subdomains',
#        'prefix_suffix', 'random_domain', 'shortening_service',
#        'path_extension', 'nb_redirection', 'nb_external_redirection',
#        'length_words_raw', 'char_repeat', 'shortest_words_raw',
#        'shortest_word_host', 'shortest_word_path', 'longest_words_raw',
#        'longest_word_host', 'longest_word_path', 'avg_words_raw',
#        'avg_word_host', 'avg_word_path', 'phish_hints', 'domain_in_brand',
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

numerical_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features)
        ('cat', categorical_transformer, categorical_features)
    ])

# %%
from sklearn.ensemble import RandomForestClassifier

final_pipeline = Pipeline(steps=
                          [
        ('preprocessor', preprocessor),
        ('classifier', RandomForestClassifier(random_state=42))
    ])


# Afficher le pipeline pour visualiser sa structure
final_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['length_url', 'length_hostname', 'ip', 'nb_dots', 'nb_hyphens', 'nb_at',
#        'nb_qm', 'nb_and', 'nb_or', 'nb_eq', 'nb_underscore', 'nb_tilde',
#        'nb_percent', 'nb_slash', 'nb_star', 'nb_colon', 'nb_comma',
#        'nb_semicolumn', 'nb_dollar', 'nb_space', 'nb_...
#        'submit_email', 'ratio_intMedia', 'ratio_extMedia', 'sfh', 'iframe',
#        'popup_window', 'safe_anchor', 'onmouseover', 'right_clic',
#        'empty_title', 'domain_in_title', 'domain_with_copyright',
#        'whois_registered_domain', 'domain_registration_length', 'domain_age',
#        'web_traffic', 'dns_record', 'google_index', 'page_rank'],
#       dtype='object'))])),
# ...

# %%
final_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['length_url', 'length_hostname', 'ip', 'nb_dots', 'nb_hyphens', 'nb_at',
#        'nb_qm', 'nb_and', 'nb_or', 'nb_eq', 'nb_underscore', 'nb_tilde',
#        'nb_percent', 'nb_slash', 'nb_star', 'nb_colon', 'nb_comma',
#        'nb_semicolumn', 'nb_dollar', 'nb_space', 'nb_...
#        'submit_email', 'ratio_intMedia', 'ratio_extMedia', 'sfh', 'iframe',
#        'popup_window', 'safe_anchor', 'onmouseover', 'right_clic',
#        'empty_title', 'domain_in_title', 'domain_with_copyright',
#        'whois_registered_domain', 'domain_registration_length', 'domain_age',
#        'web_traffic', 'dns_record', 'google_index', 'page_rank'],
#       dtype='object'))])),
# ...

# %%
y_pred = final_pipeline.predict(X_test)
y_pred
# Out:
# array(['phishing', 'legitimate', 'legitimate', ..., 'phishing',
#        'phishing', 'legitimate'], shape=(1509,), dtype=object)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print("Matrice de Confusion :")
print(confusion_matrix(y_test, y_pred))

print("\nRapport de Classification :")
print(classification_report(y_test, y_pred))
# Out:
# Matrice de Confusion :
# [[711  44]
#  [ 29 725]]
#
# Rapport de Classification :
#               precision    recall  f1-score   support
#
#   legitimate       0.96      0.94      0.95       755
#     phishing       0.94      0.96      0.95       754
#
#     accuracy                           0.95      1509
#    macro avg       0.95      0.95      0.95      1509
# weighted avg       0.95      0.95      0.95      1509

# %%
import skops.io as skio
from skops import dump
with open("phishing_url_model.skops", "wb") as f:
    dump(final_pipeline, f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[163], line 4
#       1 from skops.io import dump, load
#       3 with open("phishing_url_model.skops", "wb") as f:
# ----> 4     dump(final_pipeline, f)
#
# File ~/Cyber/2_Areas/Academics/2600/2025-10-21-llm-lionel/.venv/lib/python3.13/site-packages/skops/io/_persist.py:81, in dump(obj, file, compression, compresslevel)
#      46 def dump(
#      47     obj: Any,
#      48     file: str | Path | BinaryIO,
#    (...)     51     compresslevel: int | None = None,
#      52 ) -> None:
#      53     """Save an object using the skops persistence format.
#      54
#      55     Skops aims at providing a secure persistence feature that does not rely on
#    (...)     79         .. versionadded:: 0.7
#      80     """
# ---> 81     buffer = _save(obj, compression=compression, compresslevel=compresslevel)
# ...
